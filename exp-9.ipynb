# %%
def first_fit(items, capacity=1.0):
    bins = []  # Remaining space in each bin
    bin_contents = []

    for item in items:
        placed = False

        for i, space in enumerate(bins):
            if space >= item:
                bins[i] -= item
                bin_contents[i].append(item)
                placed = True
                break

        if not placed:
            bins.append(capacity - item)
            bin_contents.append([item])

    return bin_contents


def first_fit_decreasing(items, capacity=1.0):
    return first_fit(sorted(items, reverse=True), capacity)


def best_fit_decreasing(items, capacity=1.0):
    sorted_items = sorted(items, reverse=True)

    bins = []
    bin_contents = []

    for item in sorted_items:
        best_idx = -1
        best_space = float("inf")

        for i, space in enumerate(bins):
            if space >= item and (space - item) < best_space:
                best_space = space - item
                best_idx = i

        if best_idx >= 0:
            bins[best_idx] -= item
            bin_contents[best_idx].append(item)
        else:
            bins.append(capacity - item)
            bin_contents.append([item])

    return bin_contents


def display_bins(label, bins):
    print(f"\n{label}: {len(bins)} bins")

    for i, b in enumerate(bins, 1):
        used = sum(b)
        bar = "#" * int(used * 20)

        print(
            f" Bin {i}: {[round(x, 1) for x in b]} | "
            f"Used: {used:.1f} [{bar:<20}]"
        )


# ---------------- Main Program ----------------

items = [0.55, 0.25, 0.35, 0.75, 0.45, 0.15, 0.65, 0.85, 0.20, 0.40]
capacity = 1.0

# Lower bound using ceiling
lower_bound = -(-sum(items) // capacity)

print(f"Items: {items}")
print(f"Capacity: {capacity}")
print(f"Sum of items: {sum(items)}")
print(f"Lower Bound on bins: {int(lower_bound)}")

ff_bins = first_fit(items)
ffd_bins = first_fit_decreasing(items)
bfd_bins = best_fit_decreasing(items)

display_bins("First Fit (FF)", ff_bins)
display_bins("First Fit Decreasing (FFD)", ffd_bins)
display_bins("Best Fit Decreasing (BFD)", bfd_bins)

print(
    f"\nSummary: "
    f"Lower Bound = {int(lower_bound)}, "
    f"FF = {len(ff_bins)}, "
    f"FFD = {len(ffd_bins)}, "
    f"BFD = {len(bfd_bins)}"
)
# Out:
# Items: [0.55, 0.25, 0.35, 0.75, 0.45, 0.15, 0.65, 0.85, 0.2, 0.4]
# Capacity: 1.0
# Sum of items: 4.6000000000000005
# Lower Bound on bins: 5
#
# First Fit (FF): 6 bins
#  Bin 1: [0.6, 0.2, 0.1] | Used: 1.0 [################### ]
#  Bin 2: [0.3, 0.5, 0.2] | Used: 1.0 [####################]
#  Bin 3: [0.8] | Used: 0.8 [###############     ]
#  Bin 4: [0.7] | Used: 0.7 [#############       ]
#  Bin 5: [0.8] | Used: 0.8 [#################   ]
#  Bin 6: [0.4] | Used: 0.4 [########            ]
#
# First Fit Decreasing (FFD): 5 bins
#  Bin 1: [0.8, 0.1] | Used: 1.0 [####################]
#  Bin 2: [0.8, 0.2] | Used: 1.0 [####################]
#  Bin 3: [0.7, 0.3] | Used: 1.0 [####################]
#  Bin 4: [0.6, 0.4] | Used: 1.0 [################### ]
#  Bin 5: [0.5, 0.2] | Used: 0.7 [#############       ]
#
# Best Fit Decreasing (BFD): 5 bins
#  Bin 1: [0.8, 0.1] | Used: 1.0 [####################]
#  Bin 2: [0.8, 0.2] | Used: 1.0 [####################]
#  Bin 3: [0.7, 0.3] | Used: 1.0 [####################]
#  Bin 4: [0.6, 0.4] | Used: 1.0 [################### ]
#  Bin 5: [0.5, 0.2] | Used: 0.7 [#############       ]
#
# Summary: Lower Bound = 5, FF = 6, FFD = 5, BFD = 5
